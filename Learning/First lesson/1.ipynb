# %%
import pandas as pd

# %%
data = pd.read_csv("C:/Users/aliha/Desktop/ML/Learning/First lesson/train.csv", index_col="PassengerId")

# %%
data.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
data.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
data[(data['Embarked'] == 'C') & (data['Fare'] > 200)].sort_values(by='Fare', ascending = True).head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 378                 0       1
# 381                 1       1
# 558                 0       1
# 701                 1       1
# 717                 1       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 378                                  Widener, Mr. Harry Elkins    male  27.0
# 381                                      Bidois, Miss. Rosalie  female  42.0
# 558                                        Robbins, Mr. Victor    male   NaN
# 701          Astor, Mrs. John Jacob (Madeleine Talmadge Force)  female  18.0
# 717                              Endres, Miss. Caroline Louise  female  38.0
#
#              SibSp  Parch    Ticket     Fare    Cabin Embarked
# PassengerId
# 378              0      2    113503  211.500      C82        C
# 381              0      0  PC 17757  227.525      NaN        C
# 558              0      0  PC 17757  227.525      NaN        C
# ...

# %%
def age_category(age):
    if age < 30:
        return 1
    elif age < 55:
        return 2
    else: 
        return 3

# %%
age_categories = [age_category(age) for age in data['Age']]

# %%
data['Age_category'] = age_categories

# %%
data.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked  \
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# ...

# %%
#second way
data['Age_category'] = data['Age'].apply(age_category)

# %%
data.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked  \
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# ...

# %%
data['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
data[(data['Pclass']) & (data['Sex'] == 'female')].describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare  \
# count  238.000000  238.000000  187.000000  238.000000  238.000000  238.000000
# mean     0.684874    2.210084   27.596257    0.760504    0.663866   51.667788
# std      0.465545    0.979744   14.591414    1.271812    1.077404   64.733995
# min      0.000000    1.000000    0.750000    0.000000    0.000000    6.750000
# 25%      0.000000    1.000000   18.000000    0.000000    0.000000    9.646875
# 50%      1.000000    3.000000   26.000000    0.000000    0.000000   24.150000
# 75%      1.000000    3.000000   38.000000    1.000000    1.000000   76.619825
# max      1.000000    3.000000   63.000000    8.000000    6.000000  512.329200
#
#        Age_category
# count    238.000000
# mean       1.802521
# std        0.810580
# min        1.000000
# 25%        1.000000
# 50%        2.000000
# 75%        2.000000
# max        3.000000

# %%
data[(data['Pclass'] == 2) & (data['Sex'] != 'female')].describe()
# Out:
#          Survived  Pclass        Age       SibSp       Parch        Fare  \
# count  108.000000   108.0  99.000000  108.000000  108.000000  108.000000
# mean     0.157407     2.0  30.740707    0.342593    0.222222   19.741782
# std      0.365882     0.0  14.793894    0.566380    0.517603   14.922235
# min      0.000000     2.0   0.670000    0.000000    0.000000    0.000000
# 25%      0.000000     2.0  23.000000    0.000000    0.000000   12.331250
# 50%      0.000000     2.0  30.000000    0.000000    0.000000   13.000000
# 75%      0.000000     2.0  36.750000    1.000000    0.000000   26.000000
# max      1.000000     2.0  70.000000    2.000000    2.000000   73.500000
#
#        Age_category
# count    108.000000
# mean       1.703704
# std        0.700591
# min        1.000000
# 25%        1.000000
# 50%        2.000000
# 75%        2.000000
# max        3.000000

# %%
data['Fare'].describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64

# %%
young = (len(data[(data['Age'] < 30) & (data['Survived'] == 1)]))/len(data[data['Age'] < 30])
old = (len(data[(data['Age'] > 60) & (data['Survived'] == 1)]))/len(data[data['Age'] > 60])
print(young*100, old*100)
# Out:
# 40.625 22.727272727272727

# %%
data[(data['Age'] > 60) & (data['Survived'] == 1)].describe()
# Out:
#        Survived    Pclass        Age     SibSp  Parch       Fare  Age_category
# count       5.0  5.000000   5.000000  5.000000    5.0   5.000000           5.0
# mean        1.0  1.600000  66.000000  0.200000    0.0  41.609160           3.0
# std         0.0  0.894427   7.842194  0.447214    0.0  35.082245           0.0
# min         1.0  1.000000  62.000000  0.000000    0.0   9.587500           3.0
# 25%         1.0  1.000000  62.000000  0.000000    0.0  10.500000           3.0
# 50%         1.0  1.000000  63.000000  0.000000    0.0  30.000000           3.0
# 75%         1.0  2.000000  63.000000  0.000000    0.0  77.958300           3.0
# max         1.0  3.000000  80.000000  1.000000    0.0  80.000000           3.0

# %%
female = (len(data[(data['Sex'] == 'female') & (data['Survived'] == 1)]))/len(data[data['Sex'] == 'female'])
male = (len(data[(data['Sex'] == 'male') & (data['Survived'] == 1)]))/len(data[data['Sex'] == 'male'])
print(female*100, male*100)
# Out:
# 74.20382165605095 18.890814558058924

# %%
data[(data['Sex'] == 'male')].value_counts().idxmax()
# Out:
# (0,
#  1,
#  'Andrews, Mr. Thomas Jr',
#  'male',
#  39.0,
#  0,
#  0,
#  '112050',
#  0.0,
#  'A36',
#  'S',
#  2)

# %%
data[data['Survived'] == 1]['Age'].mean()
# Out:
# 28.343689655172415

# %%
data[data['Survived'] == 0]['Age'].mean()
# Out:
# 30.62617924528302

# %%
data[(data['Pclass'] == 1) & (data['Sex'] == 'male')]['Age'].mean()
# Out:
# 41.28138613861386

# %%
data[(data['Pclass'] == 1) & (data['Sex'] == 'female')]['Age'].mean()
# Out:
# 34.61176470588235
